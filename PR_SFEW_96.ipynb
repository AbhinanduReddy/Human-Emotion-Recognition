# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.applications import ResNet50, Xception, InceptionResNetV2
from tensorflow.keras import layers
from keras.layers.normalization import BatchNormalization
import keras
import dlib
import cv2
from sklearn import preprocessing
from imutils import face_utils
import numpy as np
from keras.optimizers import SGD,Adam
from keras.layers import UpSampling2D
from tensorflow.keras import Model

from keras.utils import to_categorical

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Dense, Activation, Dropout, Flatten

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from numpy.random import seed
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X_train = np.load('/content/drive/MyDrive/DATASETS/X_train_SFEW_96.npy')
y_train = np.load('/content/drive/MyDrive/DATASETS/y_train_SFEW_96.npy')
X_test = np.load('/content/drive/MyDrive/DATASETS/X_test_SFEW_96.npy')
y_test = np.load('/content/drive/MyDrive/DATASETS/y_test_SFEW_96.npy')

# %%
import matplotlib.pyplot as plt
print(y_train[200])
##print(le.inverse_transform(y_train_KDEF[200]))
plt.imshow(X_train[200])
plt.show()
# Out:
# 2

# %%
x_train_data = X_train
print(x_train_data.shape)
y_train_data = to_categorical(y_train, 7)
print(y_train_data.shape)
x_test_data = X_test
print(x_test_data.shape)
y_test_data = to_categorical(y_test, 7)
print(y_test_data.shape)
# Out:
# (346, 96, 96, 3)
# (346, 7)
# (354, 96, 96, 3)
# (354, 7)

# %%
from sklearn.model_selection import train_test_split
x_train_final, x_valid_final, y_train_final, y_valid_final = train_test_split(x_train_data, y_train_data, test_size=0.1, random_state=42)

# %%
from keras.models import Sequential, load_model

model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3), input_shape=(96, 96, 3), activation='relu', padding='same',name='conv96_1'))
model.add(Conv2D(64, kernel_size=(3, 3), input_shape=(96, 96, 3), activation='relu', padding='same',name='conv96_3'))

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same',name='conv96_2'))
model.add(MaxPooling2D(pool_size=(2, 2),name='maxpool96_1'))


prior = load_model('/content/drive/MyDrive/DATASETS/test_sfew_48.h5')


for layer in prior.layers[1:]:
    model.add(layer)


for layer in prior.layers[-4:]:
    print(layer)
    layer.trainable = False
from keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f66c03cb438>
# <tensorflow.python.keras.layers.core.Dense object at 0x7f66c0160eb8>
# <tensorflow.python.keras.layers.core.Dropout object at 0x7f66c03e0c88>
# <tensorflow.python.keras.layers.core.Dense object at 0x7f66c0075a90>

# %%
#sgd = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
#callbacks = [ModelCheckpoint(weights, monitor='val_loss', save_best_only=True, verbose=0)]
adam=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='categorical_crossentropy',optimizer = Adam(lr = 1e-4), metrics=['accuracy'])

#model.fit(x_train_data,y_train_data,batch_size = 64,epochs=100)
history = model.fit(x_train_final , y_train_final, batch_size=64,epochs=100,validation_data=(x_valid_final, y_valid_final),verbose=1, use_multiprocessing=True)

#model.fit(X_train, Y_train, batch_size = 1000, nb_epoch = 5, verbose = 1, shuffle = True)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 84ms/step - loss: 1.9274 - accuracy: 0.2444 - val_loss: 1.7849 - val_accuracy: 0.3143
# Epoch 2/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.7256 - accuracy: 0.3492 - val_loss: 1.5828 - val_accuracy: 0.4000
# Epoch 3/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.5631 - accuracy: 0.5019 - val_loss: 1.5354 - val_accuracy: 0.4857
# Epoch 4/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.3859 - accuracy: 0.6292 - val_loss: 1.4875 - val_accuracy: 0.4286
# Epoch 5/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.2508 - accuracy: 0.6776 - val_loss: 1.2342 - val_accuracy: 0.6857
# Epoch 6/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.0310 - accuracy: 0.7932 - val_loss: 1.0615 - val_accuracy: 0.6857
# Epoch 7/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.9211 - accuracy: 0.8085 - val_loss: 0.9502 - val_accuracy: 0.7143
# Epoch 8/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.7784 - accuracy: 0.8284 - val_loss: 0.8295 - val_accuracy: 0.7714
# Epoch 9/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.6972 - accuracy: 0.8736 - val_loss: 0.7967 - val_accuracy: 0.7429
# Epoch 10/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.6545 - accuracy: 0.8164 - val_loss: 0.7518 - val_accuracy: 0.7429
# Epoch 11/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.5675 - accuracy: 0.8661 - val_loss: 0.7216 - val_accuracy: 0.7429
# Epoch 12/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4658 - accuracy: 0.9166 - val_loss: 0.6583 - val_accuracy: 0.7429
# Epoch 13/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4370 - accuracy: 0.9058 - val_loss: 0.6436 - val_accuracy: 0.7429
# Epoch 14/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4240 - accuracy: 0.8761 - val_loss: 0.6130 - val_accuracy: 0.8000
# Epoch 15/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3646 - accuracy: 0.9006 - val_loss: 0.6081 - val_accuracy: 0.7714
# Epoch 16/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3638 - accuracy: 0.9313 - val_loss: 0.5650 - val_accuracy: 0.8286
# Epoch 17/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3304 - accuracy: 0.9352 - val_loss: 0.5853 - val_accuracy: 0.8000
# Epoch 18/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2859 - accuracy: 0.9285 - val_loss: 0.5418 - val_accuracy: 0.8000
# Epoch 19/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2757 - accuracy: 0.9423 - val_loss: 0.5324 - val_accuracy: 0.8286
# Epoch 20/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2450 - accuracy: 0.9601 - val_loss: 0.5005 - val_accuracy: 0.8571
# Epoch 21/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2111 - accuracy: 0.9693 - val_loss: 0.5693 - val_accuracy: 0.8000
# Epoch 22/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2062 - accuracy: 0.9529 - val_loss: 0.5532 - val_accuracy: 0.8286
# Epoch 23/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1998 - accuracy: 0.9490 - val_loss: 0.5967 - val_accuracy: 0.8000
# Epoch 24/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2247 - accuracy: 0.9505 - val_loss: 0.5636 - val_accuracy: 0.8000
# Epoch 25/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1712 - accuracy: 0.9750 - val_loss: 0.5429 - val_accuracy: 0.8000
# Epoch 26/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1935 - accuracy: 0.9588 - val_loss: 0.5208 - val_accuracy: 0.8286
# Epoch 27/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1802 - accuracy: 0.9659 - val_loss: 0.5185 - val_accuracy: 0.8286
# Epoch 28/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1468 - accuracy: 0.9697 - val_loss: 0.5461 - val_accuracy: 0.8286
# Epoch 29/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2222 - accuracy: 0.9280 - val_loss: 0.6817 - val_accuracy: 0.8000
# Epoch 30/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2021 - accuracy: 0.9492 - val_loss: 0.5749 - val_accuracy: 0.8286
# Epoch 31/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1870 - accuracy: 0.9408 - val_loss: 0.6266 - val_accuracy: 0.8000
# Epoch 32/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1954 - accuracy: 0.9397 - val_loss: 0.5026 - val_accuracy: 0.8571
# Epoch 33/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1521 - accuracy: 0.9481 - val_loss: 0.5257 - val_accuracy: 0.8286
# Epoch 34/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1165 - accuracy: 0.9735 - val_loss: 0.5997 - val_accuracy: 0.8000
# Epoch 35/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1311 - accuracy: 0.9663 - val_loss: 0.5514 - val_accuracy: 0.8571
# Epoch 36/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1317 - accuracy: 0.9736 - val_loss: 0.5680 - val_accuracy: 0.8000
# Epoch 37/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1020 - accuracy: 0.9706 - val_loss: 0.5812 - val_accuracy: 0.8000
# Epoch 38/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0881 - accuracy: 0.9892 - val_loss: 0.5806 - val_accuracy: 0.8286
# Epoch 39/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1072 - accuracy: 0.9823 - val_loss: 0.6163 - val_accuracy: 0.8000
# Epoch 40/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1235 - accuracy: 0.9607 - val_loss: 0.6244 - val_accuracy: 0.8000
# Epoch 41/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1224 - accuracy: 0.9674 - val_loss: 0.6261 - val_accuracy: 0.8000
# Epoch 42/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1594 - accuracy: 0.9355 - val_loss: 0.5970 - val_accuracy: 0.8000
# Epoch 43/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0951 - accuracy: 0.9765 - val_loss: 0.5863 - val_accuracy: 0.8000
# Epoch 44/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1096 - accuracy: 0.9650 - val_loss: 0.6406 - val_accuracy: 0.8000
# Epoch 45/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1202 - accuracy: 0.9555 - val_loss: 0.5992 - val_accuracy: 0.8000
# Epoch 46/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0920 - accuracy: 0.9728 - val_loss: 0.6002 - val_accuracy: 0.8286
# Epoch 47/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1023 - accuracy: 0.9697 - val_loss: 0.5617 - val_accuracy: 0.8571
# Epoch 48/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1013 - accuracy: 0.9760 - val_loss: 0.5712 - val_accuracy: 0.8000
# Epoch 49/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1097 - accuracy: 0.9601 - val_loss: 0.5387 - val_accuracy: 0.8571
# Epoch 50/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0898 - accuracy: 0.9763 - val_loss: 0.5810 - val_accuracy: 0.8000
# Epoch 51/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0968 - accuracy: 0.9786 - val_loss: 0.6743 - val_accuracy: 0.8000
# Epoch 52/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0895 - accuracy: 0.9726 - val_loss: 0.6353 - val_accuracy: 0.8000
# Epoch 53/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1096 - accuracy: 0.9652 - val_loss: 0.6802 - val_accuracy: 0.8286
# Epoch 54/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0984 - accuracy: 0.9784 - val_loss: 0.6142 - val_accuracy: 0.8000
# Epoch 55/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1407 - accuracy: 0.9531 - val_loss: 0.6365 - val_accuracy: 0.8000
# Epoch 56/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1048 - accuracy: 0.9642 - val_loss: 0.6243 - val_accuracy: 0.8000
# Epoch 57/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0879 - accuracy: 0.9749 - val_loss: 0.5782 - val_accuracy: 0.8571
# Epoch 58/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0735 - accuracy: 0.9711 - val_loss: 0.6076 - val_accuracy: 0.8000
# Epoch 59/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0802 - accuracy: 0.9754 - val_loss: 0.5663 - val_accuracy: 0.8000
# Epoch 60/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1015 - accuracy: 0.9708 - val_loss: 0.5470 - val_accuracy: 0.8571
# Epoch 61/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0735 - accuracy: 0.9836 - val_loss: 0.5575 - val_accuracy: 0.8571
# Epoch 62/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0748 - accuracy: 0.9793 - val_loss: 0.5709 - val_accuracy: 0.8000
# Epoch 63/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0845 - accuracy: 0.9765 - val_loss: 0.7344 - val_accuracy: 0.8286
# Epoch 64/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0730 - accuracy: 0.9726 - val_loss: 0.7347 - val_accuracy: 0.8000
# Epoch 65/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1060 - accuracy: 0.9637 - val_loss: 0.7238 - val_accuracy: 0.8000
# Epoch 66/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1028 - accuracy: 0.9684 - val_loss: 0.6482 - val_accuracy: 0.8000
# Epoch 67/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0820 - accuracy: 0.9829 - val_loss: 0.6073 - val_accuracy: 0.8286
# Epoch 68/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0676 - accuracy: 0.9828 - val_loss: 0.6909 - val_accuracy: 0.8286
# Epoch 69/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0876 - accuracy: 0.9780 - val_loss: 0.6365 - val_accuracy: 0.8286
# Epoch 70/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0822 - accuracy: 0.9700 - val_loss: 0.6857 - val_accuracy: 0.8286
# Epoch 71/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0901 - accuracy: 0.9574 - val_loss: 0.6425 - val_accuracy: 0.8000
# Epoch 72/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0768 - accuracy: 0.9747 - val_loss: 0.6631 - val_accuracy: 0.8000
# Epoch 73/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0903 - accuracy: 0.9747 - val_loss: 0.7435 - val_accuracy: 0.8000
# Epoch 74/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0963 - accuracy: 0.9693 - val_loss: 0.6046 - val_accuracy: 0.8286
# Epoch 75/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0914 - accuracy: 0.9695 - val_loss: 0.5963 - val_accuracy: 0.8000
# Epoch 76/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1112 - accuracy: 0.9652 - val_loss: 0.6150 - val_accuracy: 0.8000
# Epoch 77/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0658 - accuracy: 0.9836 - val_loss: 0.6186 - val_accuracy: 0.8286
# Epoch 78/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0884 - accuracy: 0.9658 - val_loss: 0.6706 - val_accuracy: 0.8000
# Epoch 79/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0643 - accuracy: 0.9792 - val_loss: 0.6241 - val_accuracy: 0.8000
# Epoch 80/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0470 - accuracy: 0.9940 - val_loss: 0.6354 - val_accuracy: 0.8286
# Epoch 81/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1508 - accuracy: 0.9585 - val_loss: 0.7591 - val_accuracy: 0.8000
# Epoch 82/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0556 - accuracy: 0.9816 - val_loss: 0.7907 - val_accuracy: 0.8000
# Epoch 83/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0528 - accuracy: 0.9844 - val_loss: 0.7169 - val_accuracy: 0.8000
# Epoch 84/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0805 - accuracy: 0.9896 - val_loss: 0.6779 - val_accuracy: 0.8000
# Epoch 85/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0804 - accuracy: 0.9782 - val_loss: 0.6807 - val_accuracy: 0.8000
# Epoch 86/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0511 - accuracy: 0.9827 - val_loss: 0.6556 - val_accuracy: 0.8286
# Epoch 87/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0742 - accuracy: 0.9775 - val_loss: 0.7241 - val_accuracy: 0.8286
# Epoch 88/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0650 - accuracy: 0.9825 - val_loss: 0.7253 - val_accuracy: 0.8286
# Epoch 89/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0797 - accuracy: 0.9784 - val_loss: 0.6837 - val_accuracy: 0.8000
# Epoch 90/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0549 - accuracy: 0.9918 - val_loss: 0.7335 - val_accuracy: 0.8000
# Epoch 91/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0673 - accuracy: 0.9857 - val_loss: 0.8265 - val_accuracy: 0.8000
# Epoch 92/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1099 - accuracy: 0.9699 - val_loss: 0.7374 - val_accuracy: 0.8286
# Epoch 93/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1350 - accuracy: 0.9554 - val_loss: 0.8405 - val_accuracy: 0.8000
# Epoch 94/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0832 - accuracy: 0.9690 - val_loss: 0.6970 - val_accuracy: 0.8286
# Epoch 95/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0954 - accuracy: 0.9570 - val_loss: 0.7284 - val_accuracy: 0.8000
# Epoch 96/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0751 - accuracy: 0.9806 - val_loss: 0.6595 - val_accuracy: 0.8286
# Epoch 97/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0556 - accuracy: 0.9821 - val_loss: 0.6817 - val_accuracy: 0.8000
# Epoch 98/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0748 - accuracy: 0.9747 - val_loss: 0.7988 - val_accuracy: 0.8000
# Epoch 99/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0584 - accuracy: 0.9857 - val_loss: 0.7059 - val_accuracy: 0.8286
# Epoch 100/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0650 - accuracy: 0.9788 - val_loss: 0.6898 - val_accuracy: 0.8286

# %%
import matplotlib.pyplot as plt             

def plot_accuracy_loss(history):
    fig = plt.figure(figsize=(10,5))
    plt.subplot(221)
    
    plt.plot(history.history['accuracy'], label = "acc")
    plt.plot(history.history['val_accuracy'], label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()
    plt.subplot(222)
    plt.plot(history.history['loss'] ,label = "loss")
    plt.plot(history.history['val_loss'], label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %%
from sklearn.metrics import classification_report
from keras.models import Sequential, load_model

#model=load_model('/content/drive/MyDrive/DATASETS/test2_48.h5')
model.summary()
predicted = model.predict(X_test)
pred_labels = np.argmax(predicted, axis = 1)
report = classification_report(y_test, pred_labels)
print(report)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv96_1 (Conv2D)            (None, 96, 96, 64)        1792
# _________________________________________________________________
# conv96_3 (Conv2D)            (None, 96, 96, 64)        36928
# _________________________________________________________________
# conv96_2 (Conv2D)            (None, 96, 96, 32)        18464
# _________________________________________________________________
# maxpool96_1 (MaxPooling2D)   (None, 48, 48, 32)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_11 (Conv2D)           multiple                  18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling multiple                  0
# _________________________________________________________________
# conv2d_12 (Conv2D)           multiple                  73856
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 2,254,887
# Trainable params: 149,536
# Non-trainable params: 2,105,351
# _________________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.28      0.31      0.29        55
#            1       0.24      0.20      0.22        41
#            2       0.22      0.10      0.14        51
#            3       0.31      0.41      0.35        59
#            4       0.29      0.37      0.32        52
#            5       0.15      0.16      0.15        50
#            6       0.40      0.35      0.37        46
#
#     accuracy                           0.27       354
#    macro avg       0.27      0.27      0.26       354
# weighted avg       0.27      0.27      0.27       354

# %%
model.save('/content/drive/MyDrive/DATASETS/test_sfew__96.h5')

# %%
model=load_model('/content/drive/MyDrive/DATASETS/test2_48.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 13,208,647
# Trainable params: 13,208,647
# Non-trainable params: 0
# _________________________________________________________________
